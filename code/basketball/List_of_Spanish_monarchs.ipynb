# %% [markdown]
# # Crazy Blood Line of Spanish monarchs

# %% [markdown]
# ## check out the Spanish royal family’s crazy family tree

# %% [markdown]
#  For my project, I want to organize the data of the monarchs of Spain.
# - Scrape Wikipedia (https://en.wikipedia.org/wiki/List_of_Spanish_monarchs)
#  All the information for all the kings and queens individually
# - I chose Spain because their family tree is sufficiently complicated.
# - For example, Felipe V reigned twice, first before abdicating to his son, than after his son died. There were stretches when Spain was a republic.
#
# - I want to visualize their family tree including their consorts.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument("- - icognito")

# driver = webdriver.Chrome(chrome_options = chrome_options)
# driver.get("https://www.wikipedia.org/")

# %%
# search_box = driver.find_element_by_xpath('//*[@id="searchInput"]')
# search_box.clear()
# search_box.send_keys("List of Spanish monarchs")

# %%
# search_button = driver.find_element_by_xpath('//*[@id="search-form"]/fieldset/button/i')
# search_button.click()

# %%
# List of Spanish monarchs
raw_html = urlopen("https://en.wikipedia.org/wiki/List_of_Spanish_monarchs").read()
raw_html
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Spanish monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Spanish_monarchs","wgTitle":"List of Spanish monarchs","wgCurRevisionId":790389133,"wgRevisionId":790389133,"wgArticleId":53014,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use dmy dates from May 2016","Articles to be expanded from April 2010","All articles to be expanded","Articles needing translation from Spanish Wikipedia","Articles containing Spanish-language text","All articles with unsourced statements","Articles with unsourced statements from Jun
# ...

# %%
# Kings of the Visigoths
# wikipedia page of 'Visigoths'
raw_Visigoths = urlopen("https://en.wikipedia.org/wiki/Visigoths#Kings_of_the_Visigoths").read()
raw_Visigoths
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Visigoths - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Visigoths","wgTitle":"Visigoths","wgCurRevisionId":790598658,"wgRevisionId":790598658,"wgArticleId":32530,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles containing Latin-language text","Articles containing Italian-language text","All articles with unsourced statements","Articles with unsourced statements from May 2017","CS1 maint: Extra text: editors list","Ancient Germanic peoples","Ethnic groups in Europe","History of the Germanic peoples","Iron Age Europe","Visigoth
# ...

# %%
# Kings of Asturias
# wikipedia page of 'List of Asturian monarchs'
raw_KingAsturias = urlopen("https://en.wikipedia.org/wiki/List_of_Asturian_monarchs").read()
raw_KingAsturias
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Asturian monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Asturian_monarchs","wgTitle":"List of Asturian monarchs","wgCurRevisionId":782870405,"wgRevisionId":782870405,"wgArticleId":179827,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles which contain graphical timelines","Asturian monarchs","History of Asturias","Lists of Spanish monarchs","Goths"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDef
# ...

# %%
# Kings of Navarre
# wikipedia page of 'List of Navarrese monarchs'
raw_KingNavarre = urlopen("https://en.wikipedia.org/wiki/List_of_Navarrese_monarchs").read()
raw_KingNavarre
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Navarrese monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Navarrese_monarchs","wgTitle":"List of Navarrese monarchs","wgCurRevisionId":781071978,"wgRevisionId":781071978,"wgArticleId":74732,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Basque","Lists of Spanish monarchs","Navarrese monarchs","Navarrese royal houses"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":[
# ...

# %%
# Kings of León
# wikipedia page of 'List of Leonese monarchs'
raw_KingLeón = urlopen("https://en.wikipedia.org/wiki/List_of_Leonese_monarchs").read()
raw_KingLeón
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Leonese monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Leonese_monarchs","wgTitle":"List of Leonese monarchs","wgCurRevisionId":782869601,"wgRevisionId":782869601,"wgArticleId":1202285,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Leonese monarchs","Lists of Spanish monarchs","Leonese royal houses"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","Feb
# ...

# %%
# Kings of Galicia
# wikipedia page of 'List of Galician monarchs'
raw_KingGalicia = urlopen("https://en.wikipedia.org/wiki/List_of_Galician_monarchs").read()
raw_KingGalicia
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Galician monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Galician_monarchs","wgTitle":"List of Galician monarchs","wgCurRevisionId":787147603,"wgRevisionId":787147603,"wgArticleId":3612228,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with Spanish-language external links","Articles with Galician-language external links","History of Galicia","Galician monarchs","Lists of Spanish monarchs"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["
# ...

# %%
# Kings of Aragon
# wikipedia page of 'List of Aragonese monarchs'
raw_KingAragon = urlopen("https://en.wikipedia.org/wiki/List_of_Aragonese_monarchs").read()
raw_KingAragon
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Aragonese monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Aragonese_monarchs","wgTitle":"List of Aragonese monarchs","wgCurRevisionId":787131952,"wgRevisionId":787131952,"wgArticleId":64184,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use dmy dates from October 2012","Articles needing additional references from March 2010","All articles needing additional references","Aragonese monarchs","Lists of Spanish monarchs","Crown of Aragon","Counts of Barcelona","Aragonese royal houses"],"wgBreakFrames":false,"wgPag
# ...

# %%
# Kings of Castile
# List of Castilian monarchs
raw_KingCastile = urlopen("https://en.wikipedia.org/wiki/List_of_Castilian_monarchs").read()
raw_KingCastile
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Castilian monarchs - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Castilian_monarchs","wgTitle":"List of Castilian monarchs","wgCurRevisionId":763123669,"wgRevisionId":763123669,"wgArticleId":69613,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Castilian monarchs","Lists of Spanish monarchs","Kingdom of Castile"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January",
# ...
